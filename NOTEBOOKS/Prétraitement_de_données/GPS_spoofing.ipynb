# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 25
#      21 # Noms des fichiers générés par le notebook 03
#      22 NOM_UAVIDS    = "UAVIDS-2025_clean.csv"
#      23 NOM_COMPOSITE = "IoT_UAV_Composite_clean.csv"
#      24
# ---> 25 df_uavids    = pd.read_csv(NETTOYEES_PATH + "\\" + UAVIDS-2025)
#      26 df_composite = pd.read_csv(NETTOYEES_PATH + "\\" + NOM_COMPOSITE)
#      27
#      28 datasets_clean = {
#
# NameError: name 'UAVIDS' is not defined
