# %%
# ============================================================
# NOTEBOOK : Chargement et exploration initiale — UAV-NIDD
# Dataset  : UAV Network Intrusion Detection Dataset
# ============================================================

# ────────────────────────────────────────
# 1. IMPORTATION DES LIBRAIRIES
# ────────────────────────────────────────
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# ────────────────────────────────────────
# 2. CHARGEMENT DU DATASET
# ────────────────────────────────────────

UAV_NIDD = r"C:\Drone_Attack_Similarity_Project\DATASET\UAV_NIDD\Normal\Normal.csv"
df = pd.read_csv(UAV_NIDD)


# ────────────────────────────────────────
# 3. APERÇU GÉNÉRAL
# ────────────────────────────────────────
df.head()

# ────────────────────────────────────────
# 4. STRUCTURE ET TYPES
# ────────────────────────────────────────
df.info()

# ────────────────────────────────────────
# 5. STATISTIQUES DESCRIPTIVES
# ────────────────────────────────────────
df.describe()

# ────────────────────────────────────────
# 6. VALEURS MANQUANTES
# ────────────────────────────────────────
print(df.isnull().sum())


# ────────────────────────────────────────
# 7. DISTRIBUTION DES CLASSES
# ────────────────────────────────────────
print(df['label'].value_counts())


df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 149434 entries, 0 to 149433
# Data columns (total 45 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   flow_duration      149434 non-null  float64
#  1   flow_byts_s        149434 non-null  float64
#  2   flow_pkts_s        149434 non-null  float64
#  3   fwd_pkts_s         149434 non-null  float64
#  4   bwd_pkts_s         149434 non-null  float64
#  5   tot_fwd_pkts       149434 non-null  int64
#  6   tot_bwd_pkts       149434 non-null  int64
#  7   totlen_fwd_pkts    149434 non-null  int64
#  8   totlen_bwd_pkts    149434 non-null  int64
#  9   fwd_pkt_len_max    149434 non-null  int64
#  10  fwd_pkt_len_min    149434 non-null  int64
#  11  fwd_pkt_len_mean   149434 non-null  float64
#  12  fwd_pkt_len_std    149434 non-null  float64
#  13  bwd_pkt_len_max    149434 non-null  int64
#  14  bwd_pkt_len_min    149434 non-null  int64
#  15  bwd_pkt_len_mean   149434 non-null  float64
#  16  bwd_pkt_len_std    149434 non-null  float64
#  17  pkt_len_max        149434 non-null  int64
#  18  pkt_len_min        149434 non-null  int64
#  19  pkt_len_mean       149434 non-null  float64
#  20  pkt_len_std        149434 non-null  float64
#  21  pkt_len_var        149434 non-null  float64
#  22  fwd_header_len     149434 non-null  int64
#  23  bwd_header_len     149434 non-null  int64
#  24  fwd_seg_size_min   149434 non-null  int64
#  25  fwd_act_data_pkts  149434 non-null  int64
#  26  flow_iat_mean      149434 non-null  float64
#  27  flow_iat_max       149434 non-null  float64
#  28  flow_iat_min       149434 non-null  float64
#  29  flow_iat_std       149434 non-null  float64
#  30  fwd_iat_tot        149434 non-null  float64
#  31  fwd_iat_max        149434 non-null  float64
#  32  fwd_iat_min        149434 non-null  float64
#  33  fwd_iat_mean       149434 non-null  float64
#  34  fwd_iat_std        149434 non-null  float64
#  35  bwd_iat_tot        149434 non-null  float64
#  36  bwd_iat_max        149434 non-null  float64
#  37  bwd_iat_min        149434 non-null  float64
#  38  bwd_iat_mean       149434 non-null  float64
#  39  bwd_iat_std        149434 non-null  float64
#  40  pkt_size_avg       149434 non-null  float64
#  41  fwd_seg_size_avg   149434 non-null  float64
#  42  subflow_fwd_pkts   149434 non-null  int64
#  43  subflow_fwd_byts   149434 non-null  int64
#  44  label              149434 non-null  str
# dtypes: float64(28), int64(16), str(1)
# memory usage: 52.1 MB
# flow_duration        0
# flow_byts_s          0
# flow_pkts_s          0
# fwd_pkts_s           0
# bwd_pkts_s           0
# tot_fwd_pkts         0
# tot_bwd_pkts         0
# totlen_fwd_pkts      0
# totlen_bwd_pkts      0
# fwd_pkt_len_max      0
# fwd_pkt_len_min      0
# fwd_pkt_len_mean     0
# fwd_pkt_len_std      0
# bwd_pkt_len_max      0
# bwd_pkt_len_min      0
# bwd_pkt_len_mean     0
# bwd_pkt_len_std      0
# pkt_len_max          0
# pkt_len_min          0
# pkt_len_mean         0
# pkt_len_std          0
# pkt_len_var          0
# fwd_header_len       0
# bwd_header_len       0
# fwd_seg_size_min     0
# fwd_act_data_pkts    0
# flow_iat_mean        0
# flow_iat_max         0
# flow_iat_min         0
# flow_iat_std         0
# fwd_iat_tot          0
# fwd_iat_max          0
# fwd_iat_min          0
# fwd_iat_mean         0
# fwd_iat_std          0
# bwd_iat_tot          0
# bwd_iat_max          0
# bwd_iat_min          0
# bwd_iat_mean         0
# bwd_iat_std          0
# pkt_size_avg         0
# fwd_seg_size_avg     0
# subflow_fwd_pkts     0
# subflow_fwd_byts     0
# label                0
# dtype: int64
# label
# Scanning       50135
# Reco           50135
# DDoS           14292
# DoS            14121
# Normal         13444
# Bruteforce      5103
# MITM            1164
# Reply            792
# FakeLanding      200
# Evil              48
# Name: count, dtype: int64
#    flow_duration  flow_byts_s  flow_pkts_s  fwd_pkts_s  bwd_pkts_s  \
# 0      10.820465    14.601960     0.277252    0.277252         0.0
# 1       4.872761    38.171378     0.615667    0.615667         0.0
# 2       0.000000     0.000000     0.000000    0.000000         0.0
# 3       7.866051    30.383734     0.381386    0.381386         0.0
# 4       0.000000     0.000000     0.000000    0.000000         0.0
#
#    tot_fwd_pkts  tot_bwd_pkts  totlen_fwd_pkts  totlen_bwd_pkts  \
# 0             3             0              158                0
# 1             3             0              186                0
# 2             2             0              180                0
# 3             3             0              239                0
# 4             2             0              122                0
#
#    fwd_pkt_len_max  ...  bwd_iat_tot  bwd_iat_max  bwd_iat_min  bwd_iat_mean  \
# 0               58  ...          0.0          0.0          0.0           0.0
# 1               64  ...          0.0          0.0          0.0           0.0
# 2               90  ...          0.0          0.0          0.0           0.0
# 3               90  ...          0.0          0.0          0.0           0.0
# 4               61  ...          0.0          0.0          0.0           0.0
#
#    bwd_iat_std  pkt_size_avg  fwd_seg_size_avg  subflow_fwd_pkts  \
# 0          0.0     52.666667         52.666667                 3
# 1          0.0     62.000000         62.000000                 3
# 2          0.0     90.000000         90.000000                 2
# 3          0.0     79.666667         79.666667                 3
# 4          0.0     61.000000         61.000000                 2
#
#    subflow_fwd_byts   label
# 0               158  Normal
# 1               186  Normal
# 2               180  Normal
# 3               239  Normal
# 4               122  Normal
#
# [5 rows x 45 columns]
